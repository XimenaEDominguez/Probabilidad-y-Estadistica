# %% [markdown]
# <a href="https://colab.research.google.com/github/XimenaEDominguez/Probabilidad-y-Estadistica/blob/main/Distribucion_binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Dominguez Morales Ximena Elizabeth

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
media=70
desv=4
Total_a=500
lim=79
x1=68
x2=72
prob_72=norm.cdf(lim,media,desv)
prob_68=norm.cdf(lim,media,desv)
probest_mas68=1-prob_68
probest_menos72=prob_72*Total_a
print(probest_mas68)
print(probest_menos72)
x=np.linspace(media-3*desv,media+3*desv,Total_a)
pdf=1/(desv*np.sqrt(2*np.pi))*np.exp(-(x-media)**2/(2*desv**2))
x=np.linspace(media-4*desv,media+4*desv,Total_a,1000)
y=norm.pdf(x,media,desv)
# Out:
# 0.012224472655044671
# 493.88776367247766

# %%
x=np.linspace(media-4*desv,media+4*desv,Total_a)
plt.plot(x,norm.pdf(x,media,desv))
y=norm.pdf(x,media,desv)

# %%
plt.plot(x,y,'b',linewidth=2)
plt.fill_between(x,y,where=(x>=x1),color='skyblue',alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 68kg.\n,x=500')
plt.xlabel("Peso en kg")
plt.ylabel("Densidad de probabilidad")
plt.grid(True)

# %%
plt.plot(x,y,'b',linewidth=2)
plt.fill_between(x,y,where=(x<=x2),color='red',alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 72kg.\n,x=500')
plt.xlabel("Peso en kg")
plt.ylabel("Densidad de probabilidad")
plt.grid(True)

# %%
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=((x >= x1) & (x <= x2)), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese entre 68kg y 72kg.\n, n=500')
plt.xlabel('Peso en kg')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
