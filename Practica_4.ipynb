# %% [markdown]
# <a href="https://colab.research.google.com/github/XimenaEDominguez/Probabilidad-y-Estadistica/blob/main/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejemplo 3: Histogramas de 2 grupos
#
# 1- En este ejemplo generamos 100 numeros aleatorios reales que representa la produccion diaria de 100 telares(medidas en metros)
#
# 2- Generar otra lista con la produccion de 100 telares para una segunda fabrica
#
# 3-Con estas listas de valores se pretende determinar las medidas de tendencia central, es decir, la media, la moda, la mediana, la desviacion estandar.
#
# 4- Graficar un histograma para cada fabrica

# %%
from statistics import *

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1= []
for i in range(100):
  numero_aleatorio= round (random.uniform(50,100) ,2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [97.69, 52.02, 83.86, 88.78, 69.49, 74.41, 98.23, 58.13, 70.72, 61.06, 69.87, 72.07, 81.07, 86.24, 91.81, 52.02, 74.22, 64.92, 64.33, 78.28, 91.88, 96.0, 80.38, 92.93, 59.53, 82.11, 80.25, 64.19, 92.06, 98.95, 92.55, 79.94, 75.04, 79.83, 70.45, 52.6, 55.34, 61.19, 58.97, 72.33, 98.54, 77.5, 81.21, 52.12, 58.16, 84.77, 86.98, 92.46, 90.07, 79.99, 79.86, 56.37, 89.43, 82.86, 87.54, 53.81, 88.19, 94.17, 75.49, 61.68, 86.27, 60.74, 96.76, 54.6, 89.12, 75.83, 77.19, 86.85, 97.9, 60.98, 82.04, 65.28, 68.49, 56.79, 95.47, 67.24, 97.48, 50.14, 98.75, 84.75, 50.71, 58.0, 60.19, 52.12, 75.11, 78.55, 79.99, 59.51, 63.16, 86.16, 96.89, 68.5, 77.94, 51.34, 84.12, 52.66, 67.13, 85.98, 90.86, 71.8]

# %%
fabrica2= []
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50,100) ,2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [84.26, 87.31, 91.76, 72.27, 91.51, 78.78, 98.45, 79.97, 50.93, 87.59, 80.53, 55.76, 86.3, 54.06, 63.99, 57.67, 94.46, 77.43, 97.37, 63.96, 90.72, 72.56, 67.33, 62.84, 75.88, 76.28, 88.53, 91.34, 99.7, 59.97, 59.51, 51.12, 86.71, 52.18, 64.76, 96.03, 54.28, 64.43, 59.53, 51.03, 53.61, 50.38, 90.07, 72.81, 65.49, 56.31, 65.01, 83.73, 56.8, 82.62, 74.95, 65.65, 78.26, 60.1, 63.55, 66.44, 83.96, 57.99, 52.58, 75.49, 92.03, 97.28, 72.89, 94.76, 96.51, 96.14, 60.41, 90.3, 64.67, 81.44, 62.48, 93.42, 62.71, 59.35, 92.17, 83.36, 75.37, 62.24, 60.24, 80.19, 86.54, 68.79, 72.06, 71.3, 65.47, 96.76, 54.56, 53.81, 72.93, 96.2, 92.88, 96.88, 76.5, 64.19, 77.83, 72.48, 76.56, 82.94, 97.57, 60.3]

# %%
#Libreria para graficar
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media=mean(fabrica1)
mediana = median(fabrica1)
moda= mode(fabrica1)

print ("Valores de la fabrica 1")
print("La media es:", media)
print("La mediana es:", mediana)
print("La moda es:", moda)
# Out:
# Valores de la fabrica 1
# La media es: 75.6033
# La mediana es: 77.72
# La moda es: 52.02

# %%
media=mean(fabrica2)
mediana = median(fabrica2)
moda= mode(fabrica2)

print ("Valores de la fabrica 2")
print("La media es:", media)
print("La mediana es:", mediana)
print("La moda es:", moda)
# Out:
# Valores de la fabrica 2
# La media es: 74.494
# La mediana es: 73.94
# La moda es: 84.26

# %%
#Generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas, una al lado de la otra
fig,(ax1,ax2) = plt.subplots(nrows =1,ncols =2)

# %%
#Generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas, una al lado de la otra
fig,(ax1,ax2) = plt.subplots(nrows =1,ncols =2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#Valor minimo, maximo, rango

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

# %%
plt.hist (fabrica1, bins=10, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media' )
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana' )
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica1")
plt.legend()
plt.show()

# %%
#Valor minimo, maximo, rango

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

# %%
plt.hist (fabrica2, bins=20, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media' )
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana' )
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica2")
plt.legend()
plt.show()

# %% [markdown]
# ## Máximo, Mínimo y Rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)
print("Estadistica descriptiva de la fabrica1", "\nmedia =", media, "\nmediana =", mediana, "\nmoda =", moda, "\nMáximo =", maximo, "\nMínimo =", minimo, "\nRango =", rango)
# Out:
# Estadistica descriptiva de la fabrica1
# media = 75.6033
# mediana = 77.72
# moda = 52.02
# Máximo = 98.95
# Mínimo = 50.14
# Rango = 48.81

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print("Estadistica descriptiva de la fabrica2", "\nmedia =", media2, "\nmediana =", mediana2, "\nmoda =", moda2, "\nMáximo =", maximo2, "\nMínimo =", minimo2, "\nRango =", rango2)
# Out:
# Estadistica descriptiva de la fabrica2
# media = 74.494
# mediana = 73.94
# moda = 84.26
# Máximo = 99.7
# Mínimo = 50.38
# Rango = 49.32

# %% [markdown]
# ## Dispersión de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviación estandar de la fabrica 1 es = ", desviacion_estandar_fabrica1 )
# Out:
# La desviación estandar de la fabrica 1 es =  14.629174190119157

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviación estandar de la fabrica 2 es = ", desviacion_estandar_fabrica2 )
# Out:
# La desviación estandar de la fabrica 2 es =  14.724060910529055

# %%
plt.figure(figsize = (10,8))
plt.hist (fabrica1, bins=10, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media1: .2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}' )
plt.axvline(media-desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar = {desviacion_estandar_fabrica1:.2f}' )
plt.axvline(media+desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar= {desviacion_estandar_fabrica1:.2f}' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.hist (fabrica1, bins=20, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'media={media2: .2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}' )
plt.axvline(media-desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar = {desviacion_estandar_fabrica2:.2f}' )
plt.axvline(media+desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar = {desviacion_estandar_fabrica2: .2f}' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
# generamosn una lista vacia que representa la edad de un grupo de personas
edades=[]

for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [32, 69, 21, 39, 34, 35, 37, 50, 22, 30, 33, 32, 32, 66, 65, 28, 40, 60, 41, 67, 41, 30, 19, 57, 30, 18, 56, 65, 32, 57, 41, 44, 36, 20, 48, 63, 39, 49, 33, 28, 47, 52, 43, 29, 64, 62, 47, 57, 44, 63, 47, 35, 50, 38, 64, 65, 19, 60, 24, 45, 64, 34, 40, 53, 57, 28, 50, 47, 58, 38, 40, 63, 31, 60, 55, 34, 55, 23, 26, 20, 21, 54, 52, 59, 28, 56, 26, 20, 54, 22, 38, 42, 20, 34, 20, 22, 48, 54, 29, 66]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame(edades, columns =["Edades"])
df_edades
# Out:
#     Edades
# 0       32
# 1       69
# 2       21
# 3       39
# 4       34
# ..     ...
# 95      22
# 96      48
# 97      54
# 98      29
# 99      66
#
# [100 rows x 1 columns]

# %%
#vincular la tabla de distribución
tabla_frecuencias = df_edades["Edades"].value_counts().reset_index()
tabla_frecuencias.columns =["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 42    18           1
# 22    19           2
# 0     20           5
# 29    21           2
# 9     22           3
# 30    23           1
# 37    24           1
# 24    26           2
# 3     28           4
# 18    29           2
# 10    30           3
# 33    31           1
# 4     32           4
# 26    33           2
# 5     34           4
# 27    35           2
# 36    36           1
# 44    37           1
# 12    38           3
# 28    39           2
# 13    40           3
# 15    41           3
# 45    42           1
# 39    43           1
# 20    44           2
# 31    45           1
# 1     47           4
# 17    48           2
# 40    49           1
# 8     50           3
# 19    52           2
# 35    53           1
# 16    54           3
# 21    55           2
# 23    56           2
# 2     57           4
# 34    58           1
# 32    59           1
# 14    60           3
# 38    62           1
# 7     63           3
# 6     64           3
# 11    65           3
# 25    66           2
# 43    67           1
# 41    69           1

# %%
tabla_frecuencias["Frec. Relativa"] = tabla_frecuencias["Frecuencia"] /100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 42    18           1            0.01
# 22    19           2            0.02
# 0     20           5            0.05
# 29    21           2            0.02
# 9     22           3            0.03
# 30    23           1            0.01
# 37    24           1            0.01
# 24    26           2            0.02
# 3     28           4            0.04
# 18    29           2            0.02
# 10    30           3            0.03
# 33    31           1            0.01
# 4     32           4            0.04
# 26    33           2            0.02
# 5     34           4            0.04
# 27    35           2            0.02
# 36    36           1            0.01
# 44    37           1            0.01
# 12    38           3            0.03
# 28    39           2            0.02
# 13    40           3            0.03
# 15    41           3            0.03
# 45    42           1            0.01
# 39    43           1            0.01
# 20    44           2            0.02
# 31    45           1            0.01
# 1     47           4            0.04
# 17    48           2            0.02
# 40    49           1            0.01
# 8     50           3            0.03
# 19    52           2            0.02
# 35    53           1            0.01
# 16    54           3            0.03
# 21    55           2            0.02
# 23    56           2            0.02
# 2     57           4            0.04
# 34    58           1            0.01
# 32    59           1            0.01
# 14    60           3            0.03
# 38    62           1            0.01
# 7     63           3            0.03
# 6     64           3            0.03
# 11    65           3            0.03
# 25    66           2            0.02
# 43    67           1            0.01
# 41    69           1            0.01

# %%
#Calcular la frecuencia porcentual
tabla_frecuencias["Frec. porcentual"] = tabla_frecuencias["Frecuencia"] /100 *100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual
# 42    18           1            0.01               1.0
# 22    19           2            0.02               2.0
# 0     20           5            0.05               5.0
# 29    21           2            0.02               2.0
# 9     22           3            0.03               3.0
# 30    23           1            0.01               1.0
# 37    24           1            0.01               1.0
# 24    26           2            0.02               2.0
# 3     28           4            0.04               4.0
# 18    29           2            0.02               2.0
# 10    30           3            0.03               3.0
# 33    31           1            0.01               1.0
# 4     32           4            0.04               4.0
# 26    33           2            0.02               2.0
# 5     34           4            0.04               4.0
# 27    35           2            0.02               2.0
# 36    36           1            0.01               1.0
# 44    37           1            0.01               1.0
# 12    38           3            0.03               3.0
# 28    39           2            0.02               2.0
# 13    40           3            0.03               3.0
# 15    41           3            0.03               3.0
# 45    42           1            0.01               1.0
# 39    43           1            0.01               1.0
# 20    44           2            0.02               2.0
# 31    45           1            0.01               1.0
# 1     47           4            0.04               4.0
# 17    48           2            0.02               2.0
# 40    49           1            0.01               1.0
# 8     50           3            0.03               3.0
# 19    52           2            0.02               2.0
# 35    53           1            0.01               1.0
# 16    54           3            0.03               3.0
# 21    55           2            0.02               2.0
# 23    56           2            0.02               2.0
# 2     57           4            0.04               4.0
# 34    58           1            0.01               1.0
# 32    59           1            0.01               1.0
# 14    60           3            0.03               3.0
# 38    62           1            0.01               1.0
# 7     63           3            0.03               3.0
# 6     64           3            0.03               3.0
# 11    65           3            0.03               3.0
# 25    66           2            0.02               2.0
# 43    67           1            0.01               1.0
# 41    69           1            0.01               1.0

# %%
#Calcular la frecuencia acumulada
# Agregamos una nueva columna con el calculo
tabla_frecuencias["Frec. Acomulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual  Frec. Acomulada
# 42    18           1            0.01               1.0                1
# 22    19           2            0.02               2.0                3
# 0     20           5            0.05               5.0                8
# 29    21           2            0.02               2.0               10
# 9     22           3            0.03               3.0               13
# 30    23           1            0.01               1.0               14
# 37    24           1            0.01               1.0               15
# 24    26           2            0.02               2.0               17
# 3     28           4            0.04               4.0               21
# 18    29           2            0.02               2.0               23
# 10    30           3            0.03               3.0               26
# 33    31           1            0.01               1.0               27
# 4     32           4            0.04               4.0               31
# 26    33           2            0.02               2.0               33
# 5     34           4            0.04               4.0               37
# 27    35           2            0.02               2.0               39
# 36    36           1            0.01               1.0               40
# 44    37           1            0.01               1.0               41
# 12    38           3            0.03               3.0               44
# 28    39           2            0.02               2.0               46
# 13    40           3            0.03               3.0               49
# 15    41           3            0.03               3.0               52
# 45    42           1            0.01               1.0               53
# 39    43           1            0.01               1.0               54
# 20    44           2            0.02               2.0               56
# 31    45           1            0.01               1.0               57
# 1     47           4            0.04               4.0               61
# 17    48           2            0.02               2.0               63
# 40    49           1            0.01               1.0               64
# 8     50           3            0.03               3.0               67
# 19    52           2            0.02               2.0               69
# 35    53           1            0.01               1.0               70
# 16    54           3            0.03               3.0               73
# 21    55           2            0.02               2.0               75
# 23    56           2            0.02               2.0               77
# 2     57           4            0.04               4.0               81
# 34    58           1            0.01               1.0               82
# 32    59           1            0.01               1.0               83
# 14    60           3            0.03               3.0               86
# 38    62           1            0.01               1.0               87
# 7     63           3            0.03               3.0               90
# 6     64           3            0.03               3.0               93
# 11    65           3            0.03               3.0               96
# 25    66           2            0.02               2.0               98
# 43    67           1            0.01               1.0               99
# 41    69           1            0.01               1.0              100

# %% [markdown]
# ## Regla de Sturges
#
# 1-. Es una regla que sirve para calcular el numero de clases o intervalos idóneo, en los que se debe de dividir un conjunto de datos.
#
# $
# c = 1 + Log _2(N)
# $

# %%
# Libreria de funciones matematicas
import math

# %%
print(edades)
# Out:
# [32, 69, 21, 39, 34, 35, 37, 50, 22, 30, 33, 32, 32, 66, 65, 28, 40, 60, 41, 67, 41, 30, 19, 57, 30, 18, 56, 65, 32, 57, 41, 44, 36, 20, 48, 63, 39, 49, 33, 28, 47, 52, 43, 29, 64, 62, 47, 57, 44, 63, 47, 35, 50, 38, 64, 65, 19, 60, 24, 45, 64, 34, 40, 53, 57, 28, 50, 47, 58, 38, 40, 63, 31, 60, 55, 34, 55, 23, 26, 20, 21, 54, 52, 59, 28, 56, 26, 20, 54, 22, 38, 42, 20, 34, 20, 22, 48, 54, 29, 66]

# %%
df_edades_sturges = pd.DataFrame( {"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     32
# 1     69
# 2     21
# 3     39
# 4     34
# ..   ...
# 95    22
# 96    48
# 97    54
# 98    29
# 99    66
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos o clases utilizando la regla de sturges
n = len(edades)
k = int(1+ math.log2(n))
print ("Valor de n=", "\nk o numero de intervalos o clases =", k )
# Out:
# Valor de n=
# k o numero de intervalos o clases = 7

# %%
plt.hist(edades, alpha=0.5, rwidth= 0.95)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
df_edades_sturges = pd.DataFrame({"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     32
# 1     69
# 2     21
# 3     39
# 4     34
# ..   ...
# 95    22
# 96    48
# 97    54
# 98    29
# 99    66
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos o clases utilizando la regla de sturges
n = len(edades)
k = int(1+ math.log2(n))
print ("Valor de n=", "\nk o numero de intervalos o clases =", k )
# Out:
# Valor de n=
# k o numero de intervalos o clases = 7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges["Edad"], bins = k ).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (25.286, 32.571]    16
# 1  (17.949, 25.286]    15
# 2  (32.571, 39.857]    15
# 3  (39.857, 47.143]    15
# 4    (61.714, 69.0]    14
# 5  (54.429, 61.714]    13
# 6  (47.143, 54.429]    12

# %%
tabla_frec_sturges.columns = ["Clase", "Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (25.286, 32.571]          16
# 1  (17.949, 25.286]          15
# 2  (32.571, 39.857]          15
# 3  (39.857, 47.143]          15
# 4    (61.714, 69.0]          14
# 5  (54.429, 61.714]          13
# 6  (47.143, 54.429]          12

# %%
# Ordenar la tabla de frecuencias por la clase o el intervalo
tabla_frec_sturges = tabla_frec_sturges.sort_values(by = "Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. Relativa  Frec. Porcentual
# 1  (17.949, 25.286]          15              31              15.0
# 0  (25.286, 32.571]          16              16              16.0
# 2  (32.571, 39.857]          15              46              15.0
# 3  (39.857, 47.143]          15              61              15.0
# 6  (47.143, 54.429]          12             100              12.0
# 5  (54.429, 61.714]          13              88              13.0
# 4    (61.714, 69.0]          14              75              14.0

# %%
tabla_frec_sturges["Frec. Relativa"] = tabla_frec_sturges["Frecuencia"] /n
tabla_frec_sturges["Frec. Porcentual"] = tabla_frec_sturges["Frecuencia"] /n *100
tabla_frec_sturges["Frec. Acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()

# %%
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. Relativa  Frec. Porcentual  \
# 1  (17.949, 25.286]          15            0.15              15.0
# 0  (25.286, 32.571]          16            0.16              16.0
# 2  (32.571, 39.857]          15            0.15              15.0
# 3  (39.857, 47.143]          15            0.15              15.0
# 6  (47.143, 54.429]          12            0.12              12.0
# 5  (54.429, 61.714]          13            0.13              13.0
# 4    (61.714, 69.0]          14            0.14              14.0
#
#    Frec. Acumulativa  Frec. Acumulada
# 1                 15               15
# 0                 31               31
# 2                 46               46
# 3                 61               61
# 6                 73               73
# 5                 86               86
# 4                100              100

# %%
plt.hist(df_edades_sturges["Edad"], bins = k, alpha=0.5, rwidth=.95)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
