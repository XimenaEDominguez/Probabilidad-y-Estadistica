# %% [markdown]
# <a href="https://colab.research.google.com/github/XimenaEDominguez/Probabilidad-y-Estadistica/blob/main/Practica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejemplo 3: Histogramas de 2 grupos
#
# 1- En este ejemplo generamos 100 numeros aleatorios reales que representa la produccion diaria de 100 telares(medidas en metros)
#
# 2- Generar otra lista con la produccion de 100 telares para una segunda fabrica
#
# 3-Con estas listas de valores se pretende determinar las medidas de tendencia central, es decir, la media, la moda, la mediana, la desviacion estandar.
#
# 4- Graficar un histograma para cada fabrica

# %%
from statistics import *

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1= []
for i in range(100):
  numero_aleatorio= round (random.uniform(50,100) ,2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [50.54, 68.22, 65.17, 53.9, 92.54, 54.42, 94.2, 78.38, 63.57, 68.86, 89.31, 85.88, 84.02, 54.15, 58.39, 75.31, 69.72, 72.66, 56.16, 93.16, 75.4, 71.13, 98.36, 77.95, 77.82, 61.95, 77.12, 71.66, 85.65, 90.86, 61.22, 79.24, 72.56, 90.1, 87.55, 65.28, 95.13, 54.16, 89.11, 70.11, 63.23, 62.66, 94.77, 85.65, 96.2, 91.3, 70.25, 51.28, 74.39, 79.26, 70.96, 74.82, 92.24, 70.46, 61.74, 67.48, 67.17, 61.01, 53.27, 55.92, 98.32, 83.67, 92.38, 58.82, 72.95, 51.75, 75.2, 57.05, 90.65, 95.62, 78.5, 54.26, 77.04, 99.54, 62.56, 52.9, 52.44, 53.15, 86.52, 68.18, 53.4, 90.16, 92.33, 78.34, 59.55, 59.89, 91.72, 86.16, 82.96, 90.84, 87.21, 73.4, 94.81, 64.35, 90.58, 61.59, 96.7, 96.66, 56.07, 54.26]

# %%
fabrica2= []
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50,100) ,2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [72.07, 76.92, 54.89, 76.56, 80.61, 51.87, 70.82, 56.69, 50.89, 61.14, 70.01, 83.32, 85.1, 50.31, 84.36, 51.4, 53.0, 87.16, 65.1, 75.77, 76.56, 81.65, 51.08, 97.25, 79.52, 82.59, 78.42, 83.53, 88.19, 89.79, 85.79, 85.19, 74.13, 78.66, 51.6, 91.25, 99.25, 91.11, 94.86, 84.06, 60.77, 92.58, 69.88, 99.83, 67.76, 63.11, 96.03, 96.76, 90.03, 82.2, 73.95, 50.97, 77.53, 78.94, 81.71, 50.37, 50.71, 73.21, 69.94, 84.21, 74.78, 79.75, 52.17, 73.27, 55.45, 84.23, 55.6, 60.88, 91.27, 65.61, 78.84, 72.18, 76.86, 52.71, 82.46, 69.29, 89.67, 64.09, 70.18, 73.67, 67.67, 60.72, 77.86, 98.91, 58.25, 64.27, 78.38, 72.07, 98.86, 76.7, 50.63, 84.13, 54.3, 68.24, 53.96, 89.37, 78.43, 91.86, 85.8, 51.81]

# %%
#Libreria para graficar
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media=mean(fabrica1)
mediana = median(fabrica1)
moda= mode(fabrica1)

print ("Valores de la fabrica 1")
print("La media es:", media)
print("La mediana es:", mediana)
print("La moda es:", moda)
# Out:
# Valores de la fabrica 1
# La media es: 74.4746
# La mediana es: 73.89500000000001
# La moda es: 85.65

# %%
media=mean(fabrica2)
mediana = median(fabrica2)
moda= mode(fabrica2)

print ("Valores de la fabrica 2")
print("La media es:", media)
print("La mediana es:", mediana)
print("La moda es:", moda)
# Out:
# Valores de la fabrica 2
# La media es: 73.9814
# La mediana es: 76.56
# La moda es: 72.07

# %%
#Generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas, una al lado de la otra
fig,(ax1,ax2) = plt.subplots(nrows =1,ncols =2)

# %%
#Generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas, una al lado de la otra
fig,(ax1,ax2) = plt.subplots(nrows =1,ncols =2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#Valor minimo, maximo, rango

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

# %%
plt.hist (fabrica1, bins=10, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media' )
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana' )
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica1")
plt.legend()
plt.show()

# %%
#Valor minimo, maximo, rango

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

# %%
plt.hist (fabrica2, bins=20, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media' )
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana' )
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica2")
plt.legend()
plt.show()

# %% [markdown]
# ## Máximo, Mínimo y Rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)
print("Estadistica descriptiva de la fabrica1", "\nmedia =", media, "\nmediana =", mediana, "\nmoda =", moda, "\nMáximo =", maximo, "\nMínimo =", minimo, "\nRango =", rango)
# Out:
# Estadistica descriptiva de la fabrica1
# media = 74.4746
# mediana = 73.89500000000001
# moda = 85.65
# Máximo = 99.54
# Mínimo = 50.54
# Rango = 49.00000000000001

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print("Estadistica descriptiva de la fabrica2", "\nmedia =", media2, "\nmediana =", mediana2, "\nmoda =", moda2, "\nMáximo =", maximo2, "\nMínimo =", minimo2, "\nRango =", rango2)
# Out:
# Estadistica descriptiva de la fabrica2
# media = 73.9814
# mediana = 76.56
# moda = 72.07
# Máximo = 99.83
# Mínimo = 50.31
# Rango = 49.519999999999996

# %% [markdown]
# ## Dispersión de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviación estandar de la fabrica 1 es = ", desviacion_estandar_fabrica1 )
# Out:
# La desviación estandar de la fabrica 1 es =  14.739917726563421

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviación estandar de la fabrica 2 es = ", desviacion_estandar_fabrica2 )
# Out:
# La desviación estandar de la fabrica 2 es =  14.289606240378022

# %%
plt.figure(figsize = (10,8))
plt.hist (fabrica1, bins=10, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media1: .2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}' )
plt.axvline(media-desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar = {desviacion_estandar_fabrica1:.2f}' )
plt.axvline(media+desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar= {desviacion_estandar_fabrica1:.2f}' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.hist (fabrica1, bins=20, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'media={media2: .2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}' )
plt.axvline(media-desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar = {desviacion_estandar_fabrica2:.2f}' )
plt.axvline(media+desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar = {desviacion_estandar_fabrica2: .2f}' )
plt.xlabel('Valor')
plt.ylabel('frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
# generamosn una lista vacia que representa la edad de un grupo de personas
edades=[]

for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [47, 22, 70, 56, 19, 23, 58, 60, 27, 70, 38, 65, 66, 63, 69, 42, 32, 64, 45, 68, 37, 51, 66, 58, 47, 55, 31, 54, 51, 50, 53, 27, 69, 48, 49, 50, 35, 39, 18, 55, 20, 27, 34, 69, 42, 20, 48, 19, 53, 64, 67, 54, 43, 27, 64, 55, 21, 38, 30, 33, 58, 50, 40, 31, 38, 30, 39, 19, 60, 58, 53, 58, 52, 49, 20, 65, 53, 18, 66, 47, 45, 47, 35, 26, 40, 18, 43, 35, 19, 67, 65, 38, 56, 38, 39, 59, 26, 38, 39, 29]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame(edades, columns =["Edades"])
df_edades
# Out:
#     Edades
# 0       47
# 1       22
# 2       70
# 3       56
# 4       19
# ..     ...
# 95      59
# 96      26
# 97      38
# 98      39
# 99      29
#
# [100 rows x 1 columns]

# %%
#vincular la tabla de distribución
tabla_frecuencias = df_edades["Edades"].value_counts().reset_index()
tabla_frecuencias.columns =["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 9     18           3
# 3     19           4
# 8     20           3
# 36    21           1
# 33    22           1
# 32    23           1
# 18    26           2
# 5     27           4
# 42    29           1
# 20    30           2
# 28    31           2
# 31    32           1
# 38    33           1
# 34    34           1
# 10    35           3
# 35    37           1
# 0     38           6
# 4     39           4
# 19    40           2
# 16    42           2
# 21    43           2
# 30    45           2
# 2     47           4
# 17    48           2
# 25    49           2
# 11    50           3
# 29    51           2
# 39    52           1
# 6     53           4
# 27    54           2
# 13    55           3
# 24    56           2
# 1     58           5
# 41    59           1
# 26    60           2
# 40    63           1
# 12    64           3
# 15    65           3
# 14    66           3
# 22    67           2
# 37    68           1
# 7     69           3
# 23    70           2

# %%
tabla_frecuencias["Frec. Relativa"] = tabla_frecuencias["Frecuencia"] /100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 9     18           3            0.03
# 3     19           4            0.04
# 8     20           3            0.03
# 36    21           1            0.01
# 33    22           1            0.01
# 32    23           1            0.01
# 18    26           2            0.02
# 5     27           4            0.04
# 42    29           1            0.01
# 20    30           2            0.02
# 28    31           2            0.02
# 31    32           1            0.01
# 38    33           1            0.01
# 34    34           1            0.01
# 10    35           3            0.03
# 35    37           1            0.01
# 0     38           6            0.06
# 4     39           4            0.04
# 19    40           2            0.02
# 16    42           2            0.02
# 21    43           2            0.02
# 30    45           2            0.02
# 2     47           4            0.04
# 17    48           2            0.02
# 25    49           2            0.02
# 11    50           3            0.03
# 29    51           2            0.02
# 39    52           1            0.01
# 6     53           4            0.04
# 27    54           2            0.02
# 13    55           3            0.03
# 24    56           2            0.02
# 1     58           5            0.05
# 41    59           1            0.01
# 26    60           2            0.02
# 40    63           1            0.01
# 12    64           3            0.03
# 15    65           3            0.03
# 14    66           3            0.03
# 22    67           2            0.02
# 37    68           1            0.01
# 7     69           3            0.03
# 23    70           2            0.02

# %%
#Calcular la frecuencia porcentual
tabla_frecuencias["Frec. porcentual"] = tabla_frecuencias["Frecuencia"] /100 *100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual
# 9     18           3            0.03               3.0
# 3     19           4            0.04               4.0
# 8     20           3            0.03               3.0
# 36    21           1            0.01               1.0
# 33    22           1            0.01               1.0
# 32    23           1            0.01               1.0
# 18    26           2            0.02               2.0
# 5     27           4            0.04               4.0
# 42    29           1            0.01               1.0
# 20    30           2            0.02               2.0
# 28    31           2            0.02               2.0
# 31    32           1            0.01               1.0
# 38    33           1            0.01               1.0
# 34    34           1            0.01               1.0
# 10    35           3            0.03               3.0
# 35    37           1            0.01               1.0
# 0     38           6            0.06               6.0
# 4     39           4            0.04               4.0
# 19    40           2            0.02               2.0
# 16    42           2            0.02               2.0
# 21    43           2            0.02               2.0
# 30    45           2            0.02               2.0
# 2     47           4            0.04               4.0
# 17    48           2            0.02               2.0
# 25    49           2            0.02               2.0
# 11    50           3            0.03               3.0
# 29    51           2            0.02               2.0
# 39    52           1            0.01               1.0
# 6     53           4            0.04               4.0
# 27    54           2            0.02               2.0
# 13    55           3            0.03               3.0
# 24    56           2            0.02               2.0
# 1     58           5            0.05               5.0
# 41    59           1            0.01               1.0
# 26    60           2            0.02               2.0
# 40    63           1            0.01               1.0
# 12    64           3            0.03               3.0
# 15    65           3            0.03               3.0
# 14    66           3            0.03               3.0
# 22    67           2            0.02               2.0
# 37    68           1            0.01               1.0
# 7     69           3            0.03               3.0
# 23    70           2            0.02               2.0

# %%
#Calcular la frecuencia acumulada
# Agregamos una nueva columna con el calculo
tabla_frecuencias["Frec. Acomulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual  Frec. Acomulada
# 9     18           3            0.03               3.0                3
# 3     19           4            0.04               4.0                7
# 8     20           3            0.03               3.0               10
# 36    21           1            0.01               1.0               11
# 33    22           1            0.01               1.0               12
# 32    23           1            0.01               1.0               13
# 18    26           2            0.02               2.0               15
# 5     27           4            0.04               4.0               19
# 42    29           1            0.01               1.0               20
# 20    30           2            0.02               2.0               22
# 28    31           2            0.02               2.0               24
# 31    32           1            0.01               1.0               25
# 38    33           1            0.01               1.0               26
# 34    34           1            0.01               1.0               27
# 10    35           3            0.03               3.0               30
# 35    37           1            0.01               1.0               31
# 0     38           6            0.06               6.0               37
# 4     39           4            0.04               4.0               41
# 19    40           2            0.02               2.0               43
# 16    42           2            0.02               2.0               45
# 21    43           2            0.02               2.0               47
# 30    45           2            0.02               2.0               49
# 2     47           4            0.04               4.0               53
# 17    48           2            0.02               2.0               55
# 25    49           2            0.02               2.0               57
# 11    50           3            0.03               3.0               60
# 29    51           2            0.02               2.0               62
# 39    52           1            0.01               1.0               63
# 6     53           4            0.04               4.0               67
# 27    54           2            0.02               2.0               69
# 13    55           3            0.03               3.0               72
# 24    56           2            0.02               2.0               74
# 1     58           5            0.05               5.0               79
# 41    59           1            0.01               1.0               80
# 26    60           2            0.02               2.0               82
# 40    63           1            0.01               1.0               83
# 12    64           3            0.03               3.0               86
# 15    65           3            0.03               3.0               89
# 14    66           3            0.03               3.0               92
# 22    67           2            0.02               2.0               94
# 37    68           1            0.01               1.0               95
# 7     69           3            0.03               3.0               98
# 23    70           2            0.02               2.0              100

# %% [markdown]
# ## Regla de Sturges
#
# 1-. Es una regla que sirve para calcular el numero de clases o intervalos idóneo, en los que se debe de dividir un conjunto de datos.
#
# $
# c = 1 + Log _2(N)
# $

# %%
# Libreria de funciones matematicas
import math

# %%
print(edades)
# Out:
# [47, 22, 70, 56, 19, 23, 58, 60, 27, 70, 38, 65, 66, 63, 69, 42, 32, 64, 45, 68, 37, 51, 66, 58, 47, 55, 31, 54, 51, 50, 53, 27, 69, 48, 49, 50, 35, 39, 18, 55, 20, 27, 34, 69, 42, 20, 48, 19, 53, 64, 67, 54, 43, 27, 64, 55, 21, 38, 30, 33, 58, 50, 40, 31, 38, 30, 39, 19, 60, 58, 53, 58, 52, 49, 20, 65, 53, 18, 66, 47, 45, 47, 35, 26, 40, 18, 43, 35, 19, 67, 65, 38, 56, 38, 39, 59, 26, 38, 39, 29]

# %%
df_edades_sturges = pd.DataFrame( {"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     47
# 1     22
# 2     70
# 3     56
# 4     19
# ..   ...
# 95    59
# 96    26
# 97    38
# 98    39
# 99    29
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos o clases utilizando la regla de sturges
n = len(edades)
k = int(1+ math.log2(n))
print ("Valor de n=", "\nk o numero de intervalos o clases =", k )
# Out:
# Valor de n=
# k o numero de intervalos o clases = 7

# %%
plt.hist(edades, alpha=0.5, rwidth= 0.95)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
df_edades_sturges = pd.DataFrame({"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     47
# 1     22
# 2     70
# 3     56
# 4     19
# ..   ...
# 95    59
# 96    26
# 97    38
# 98    39
# 99    29
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos o clases utilizando la regla de sturges
n = len(edades)
k = int(1+ math.log2(n))
print ("Valor de n=", "\nk o numero de intervalos o clases =", k )
# Out:
# Valor de n=
# k o numero de intervalos o clases = 7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges["Edad"], bins = k ).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (47.714, 55.143]    19
# 1  (32.857, 40.286]    18
# 2    (62.571, 70.0]    18
# 3  (17.948, 25.429]    13
# 4  (25.429, 32.857]    12
# 5  (40.286, 47.714]    10
# 6  (55.143, 62.571]    10

# %%
tabla_frec_sturges.columns = ["Clase", "Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (47.714, 55.143]          19
# 1  (32.857, 40.286]          18
# 2    (62.571, 70.0]          18
# 3  (17.948, 25.429]          13
# 4  (25.429, 32.857]          12
# 5  (40.286, 47.714]          10
# 6  (55.143, 62.571]          10

# %%
# Ordenar la tabla de frecuencias por la clase o el intervalo
tabla_frec_sturges = tabla_frec_sturges.sort_values(by = "Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 3  (17.948, 25.429]          13
# 4  (25.429, 32.857]          12
# 1  (32.857, 40.286]          18
# 5  (40.286, 47.714]          10
# 0  (47.714, 55.143]          19
# 6  (55.143, 62.571]          10
# 2    (62.571, 70.0]          18

# %%
tabla_frec_sturges["Frec. Relativa"] = tabla_frec_sturges["Frecuencia"] /n
tabla_frec_sturges["Frec. Porcentual"] = tabla_frec_sturges["Frecuencia"] /n *100
tabla_frec_sturges["Frec. Acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()

# %%
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. Relativa  Frec. Porcentual  \
# 3  (17.948, 25.429]          13            0.13              13.0
# 4  (25.429, 32.857]          12            0.12              12.0
# 1  (32.857, 40.286]          18            0.18              18.0
# 5  (40.286, 47.714]          10            0.10              10.0
# 0  (47.714, 55.143]          19            0.19              19.0
# 6  (55.143, 62.571]          10            0.10              10.0
# 2    (62.571, 70.0]          18            0.18              18.0
#
#    Frec. Acumulada
# 3               13
# 4               25
# 1               43
# 5               53
# 0               72
# 6               82
# 2              100

# %%
plt.hist(df_edades_sturges["Edad"], bins = k, alpha=0.5, rwidth=.95)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
print(fabrica1)
# Out:
# [50.54, 68.22, 65.17, 53.9, 92.54, 54.42, 94.2, 78.38, 63.57, 68.86, 89.31, 85.88, 84.02, 54.15, 58.39, 75.31, 69.72, 72.66, 56.16, 93.16, 75.4, 71.13, 98.36, 77.95, 77.82, 61.95, 77.12, 71.66, 85.65, 90.86, 61.22, 79.24, 72.56, 90.1, 87.55, 65.28, 95.13, 54.16, 89.11, 70.11, 63.23, 62.66, 94.77, 85.65, 96.2, 91.3, 70.25, 51.28, 74.39, 79.26, 70.96, 74.82, 92.24, 70.46, 61.74, 67.48, 67.17, 61.01, 53.27, 55.92, 98.32, 83.67, 92.38, 58.82, 72.95, 51.75, 75.2, 57.05, 90.65, 95.62, 78.5, 54.26, 77.04, 99.54, 62.56, 52.9, 52.44, 53.15, 86.52, 68.18, 53.4, 90.16, 92.33, 78.34, 59.55, 59.89, 91.72, 86.16, 82.96, 90.84, 87.21, 73.4, 94.81, 64.35, 90.58, 61.59, 96.7, 96.66, 56.07, 54.26]

# %%
plt.boxplot(fabrica1)
plt.title("Producción de fabrica 1")
plt.ylabel("Producción en metros")
plt.show()

# %%
plt.boxplot(fabrica2)
plt.title("Producción de fabrica 2")
plt.ylabel("Producción en metros")
plt.show()

# %% [markdown]
# ### Comparamos la producción de la fabrica 1 y laq fabrica 2 con un Diagrama de Cajas y Bigotes

# %%
fig, (ax1, ax2) = plt.subplots(nrows= 1, ncols=2, figsize=(9,5))
ax1.boxplot( fabrica1, vert = True, patch_artist=True)
ax1.set_title("Producción de la fabrica 1")
ax2.boxplot( fabrica2, vert = True, patch_artist=True)
ax2.set_title("Producción de la fabrica 2")
plt.show()

# %%
print(fabrica2)
# Out:
# [72.07, 76.92, 54.89, 76.56, 80.61, 51.87, 70.82, 56.69, 50.89, 61.14, 70.01, 83.32, 85.1, 50.31, 84.36, 51.4, 53.0, 87.16, 65.1, 75.77, 76.56, 81.65, 51.08, 97.25, 79.52, 82.59, 78.42, 83.53, 88.19, 89.79, 85.79, 85.19, 74.13, 78.66, 51.6, 91.25, 99.25, 91.11, 94.86, 84.06, 60.77, 92.58, 69.88, 99.83, 67.76, 63.11, 96.03, 96.76, 90.03, 82.2, 73.95, 50.97, 77.53, 78.94, 81.71, 50.37, 50.71, 73.21, 69.94, 84.21, 74.78, 79.75, 52.17, 73.27, 55.45, 84.23, 55.6, 60.88, 91.27, 65.61, 78.84, 72.18, 76.86, 52.71, 82.46, 69.29, 89.67, 64.09, 70.18, 73.67, 67.67, 60.72, 77.86, 98.91, 58.25, 64.27, 78.38, 72.07, 98.86, 76.7, 50.63, 84.13, 54.3, 68.24, 53.96, 89.37, 78.43, 91.86, 85.8, 51.81]

# %%
fabrica2.append(150)
print (fabrica2)
# Out:
# [72.07, 76.92, 54.89, 76.56, 80.61, 51.87, 70.82, 56.69, 50.89, 61.14, 70.01, 83.32, 85.1, 50.31, 84.36, 51.4, 53.0, 87.16, 65.1, 75.77, 76.56, 81.65, 51.08, 97.25, 79.52, 82.59, 78.42, 83.53, 88.19, 89.79, 85.79, 85.19, 74.13, 78.66, 51.6, 91.25, 99.25, 91.11, 94.86, 84.06, 60.77, 92.58, 69.88, 99.83, 67.76, 63.11, 96.03, 96.76, 90.03, 82.2, 73.95, 50.97, 77.53, 78.94, 81.71, 50.37, 50.71, 73.21, 69.94, 84.21, 74.78, 79.75, 52.17, 73.27, 55.45, 84.23, 55.6, 60.88, 91.27, 65.61, 78.84, 72.18, 76.86, 52.71, 82.46, 69.29, 89.67, 64.09, 70.18, 73.67, 67.67, 60.72, 77.86, 98.91, 58.25, 64.27, 78.38, 72.07, 98.86, 76.7, 50.63, 84.13, 54.3, 68.24, 53.96, 89.37, 78.43, 91.86, 85.8, 51.81, 150]

# %%
plt.boxplot(fabrica2)
plt.title("Producción de fabrica 2")
plt.ylabel("Producción en metros")
plt.show()
